# %% [markdown]
# # Test de extraccion de datos
#
# Utilizare como prueba la pagina **Lonza**: https://www.lonza.com/careers/job-search para la extraccion de los datos.
#
# 1. Primero definiremos nuestra URL seed aplicando los criterios de filtrado:
#
# Seed: https://www.lonza.com/careers/job-search?q=data,%20biotech,%20Biostatistics,%20%20clinical%20research&pg=1&rows=100&job_location_facet_sm=Switzerland%2c+Basel

# %%
# IMPORTAMOS LAS LIBRERIAS QUE VAMOS UTILIZAR

import requests
from lxml import html

# %%
# USER AGENT PARA PROTEGERNOS DE BANEOS
headers = {
    "user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/71.0.3578.80 Chrome/71.0.3578.80 Safari/537.36",
}

# %%
# URL SEED
seed = "https://www.lonza.com/careers/job-search?q=data,%20biotech,%20Biostatistics,%20%20clinical%20research&pg=1&rows=100&job_location_facet_sm=Switzerland%2c+Basel"

# %%
# REQUERIMIENTO AL SERVIDOR
respuesta = requests.get(seed, headers=headers)

# %%
respuesta
# Out:
# <Response [200]>

# %%
# print(respuesta.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
# <meta http-equiv="X-UA-Compatible" content="ie=edge">
# <title>Global Job Search | Lonza</title>
# <meta name="description" content="Find your job opportunity at Lonza and become part of our global teams. Submit your application now and get one step closer to making a meaningful difference." />
# <meta property="og:title" content="Global Job Search | Lonza" />
# <meta property="og:site_name" content="Job Search | Lonza" />
# <meta property="og:description" content="Search for openings and apply for positions at Lonza locations worldwide." />
# <meta property="og:image" content="" />
# <meta name="robots" content="" />
# <meta name="country" content="" />
#
#
#     <!-- External Stylesheets (pre custom) -->
#     <link rel="stylesheet" href="/Assets/vendor/outdatedbrowser/outdatedbrowser.min.css" />
#     <link rel="preload" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.css" as="style" />
#     <link rel="preload" href="https://cdnjs.cloudflare.com/ajax/libs/magnific-popup.js/1.1.0/magnific-popup.min.css" as="style"/>
#     <link rel="preload" href="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.8.1/slick.min.css" as="style" />
#     <link rel="preload" href="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.8.1/slick-theme.min.css" as="style" />
#
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.css" />
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/magnific-popup.js/1.1.0/magnific-popup.min.css" media="print" onload="this.media='all'" />
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.8.1/slick.min.css" media="print" onload="this.media='all'" />
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.8.1/slick-theme.min.css" media="print" onload="this.media='all'" />
#
#
# <!-- inject:css -->
# <link rel="preload" href="/Assets/lonza/css/lonza.a0cd24d161ae650bd705696bec4471970985e783.css" as "style"/><link rel="stylesheet" href="/Assets/lonza/css/lonza.a0cd24d161ae650bd705696bec4471970985e783.css"/>
# <!-- endinject -->    <!-- form styles -->
#
#
#     <!-- fav icon setting-->
# <meta name="google-site-verification" content="_sQcCmF67SDeqcXnnsSpVvAN3LxGQgOIUAty0x4L8ys" />
# <meta name="google-site-verification" content="-0nIJBqfeTZkczYx3pxysb1PhWXSpYGeu7HwR0mgcNE" />
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PJ62ZHP');</script>
# <!-- End Google Tag Manager -->
#
# <style>
# #consent-banner {
#     position: fixed;
#     left: 0;
#     right: 0;
#     bottom: 0;
#     z-index: 95000;
# }
# #consent-banner,#teconsent {font-family:Matter, Arial, sans-serif !important;}
# .trustarc-banner-header,.trustarc-header-text {font-family:Matter, Arial, sans-serif !important;}
# body:focus {outline: none !important;}
# a#icon-id04051092759554411 {margin: 0px 0px 10px 15px !important;}
# .trustarc-primary-btn,.trustarc-declineall-btn,.trustarc-acceptall-btn, #truste-consent-button, #truste-consent-required {border: 1px solid #000000 !important; background-color: rgba(0,0,0,.67) !important; color: #ffffff !important;}
# .trustarc-primary-btn:hover,.trustarc-declineall-btn:hover,.trustarc-acceptall-btn:hover, #truste-consent-button:hover, #truste-consent-required:hover {border: 1px solid #000000 !important; background-color: rgba(0,0,0,1) !important; color: #ffffff !important;}
# </style>
#
#
# <style>
#
# </style>
# <style>.page-background
# {
# display: none;
# }</style>
#
#     <!-- External Fonts -->
#     <link rel="stylesheet" href="https://use.typekit.net/ozb7wjy.css" media="print" onload="this.media='all'">
#     <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700" media="print" onload="this.media='all'">
#
#     <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#     <script type="text/javascript" src="//cdn.bizible.com/scripts/bizible.js" async></script>
#     <script src="https://www.google.com/recaptcha/api.js" async></script>
#     <script src="https://kit.fontawesome.com/713829e36f.js" defer></script>
#
#     <!-- form scripts from https://kb.sitecore.net/articles/267285 -->
#     <link rel="preload" href="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.6.0/jquery.min.js" as="script"/>
#     <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.6.0/jquery.min.js"></script>
#     <!--<script src="/sitecore%20modules/Web/ExperienceForms/scripts/jquery-2.1.3.min.js"></script>-->
#     <script src="/sitecore%20modules/Web/ExperienceForms/scripts/jquery.validate.min.js"></script>
#     <script src="/sitecore%20modules/Web/ExperienceForms/scripts/jquery.validate.unobtrusive.min.js"></script>
#     <script src="/sitecore%20modules/Web/ExperienceForms/scripts/jquery.unobtrusive-ajax.min.js"></script>
#     <script src="/sitecore%20modules/Web/ExperienceForms/scripts/form.validate.js"></script>
#     <script src="/sitecore%20modules/Web/ExperienceForms/scripts/form.tracking.js"></script>
#     <script src="/sitecore%20modules/Web/ExperienceForms/scripts/form.conditions.js"></script>
#     <script src="/sitecore%20modules/Web/ExperienceForms/scripts/formsextensions.validate.js"></script>
#     <script src="/Assets/vendor/outdatedbrowser/outdatedbrowser.min.js"></script>
#
#     <link rel="preload" href="https://stackpath.bootstrapcdn.com/bootstrap/4.1.1/js/bootstrap.bundle.min.js" as="script" />
#     <link rel="preload" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js" as="script" />
#
# </head>
# <body class="detail-page theme-corporate sc-view">
#     <!-- div for outdated browser plugin-->
#     <div id="outdated"></div>
#     <div class="position-relative">
#         <header id="header">
#
#
#     <div class="nav-wrap">
#         <div class="container-fluid container-fluid--max">
#             <div class="navbar navbar-expand-lg">
#
#
#
#                 <a class="navbar-brand svg-container--white" href="/">
# <?xml version="1.0" encoding="utf-8" ?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="155" height="28">
# 	<defs>
# 		<clipPath id="clip_0">
# 			<rect x="-150" y="-249" width="2380" height="1029" clip-rule="evenodd"/>
# 		</clipPath>
# 	</defs>
# 	<g clip-path="url(#clip_0)">
# 		<path fill="rgb(255,255,255)" stroke="none" d="M0 26.7826L0 0L10.2775 0L10.2775 18.5884L24.2188 18.5884L24.2188 26.7826L0 26.7826ZM25.4297 14.0253C25.4297 5.09103 32.8126 0 41.1719 0C49.5325 0 56.9141 5.09103 56.9141 14.0253C56.9141 22.9581 49.4806 28 41.1719 28C32.8632 28 25.4297 22.9581 25.4297 14.0253ZM146.007 3.30603L146.007 0.617107L155 0.617107L155 27.1985L146.007 27.1985L146.007 24.4804L145.878 24.651C143.825 27.4189 140.597 28 138.25 28C130.541 28 124.727 21.9704 124.727 13.9743C124.727 9.76831 126.048 6.1461 128.447 3.77475C130.91 1.34099 134.356 0 138.149 0C140.925 0 144.078 1.18706 145.883 3.17013L146.007 3.30603ZM69.6808 4.1215C71.4551 1.4129 74.4876 0.0455988 77.3173 0.00180125C84.3242 -0.103586 89.6094 4.42261 89.6094 11.7204L89.6094 26.7826L80.4836 26.7826L80.4755 14.3975C80.4755 10.4407 78.8025 8.47114 75.6011 8.18783C73.5997 8.01127 69.6618 9.1678 69.6808 13.8979L69.6808 26.7826L60.5469 26.7826L60.5469 0.729935L69.6808 0.729935L69.6808 4.1215ZM123.516 1.21739L123.428 1.33026C123.006 1.8704 113.831 13.8515 110.752 17.912C110.752 17.912 109.741 19.2449 109.716 19.2798L122.545 19.2798L122.545 26.7826L93.2422 26.7826L93.3299 26.6724C93.8298 26.0302 106.825 9.1757 107.376 8.45686C107.376 8.45686 107.41 8.42327 107.435 8.39774L94.6946 8.39774L94.6946 1.21739L123.516 1.21739ZM35.1172 14C35.1172 17.7489 38.0467 20.6957 41.7773 20.6957C45.5094 20.6957 48.4375 17.7489 48.4375 14C48.4375 10.2497 45.5094 7.30435 41.7773 7.30435C38.0467 7.30435 35.1172 10.2497 35.1172 14ZM141.182 20.6957C137.45 20.6957 134.414 17.6905 134.414 14C134.414 10.308 137.45 7.30435 141.182 7.30435C144.915 7.30435 147.734 10.308 147.734 14C147.734 17.6905 144.915 20.6957 141.182 20.6957Z" fill-rule="evenodd"/>
# 	</g>
# </svg>
#                 </a>
#
#
#                 <div class="navbar-utilities">
#
#                     <div class="main-nav d-none d-lg-block">
#                         <ul class="list-inline">
#                                     <li class="dropdown dropdown--hoverable allow-focus">
#                                             <span id="OurOfferingMenuLink" class="dropdown-toggle" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">Our Offering</span>
#                                         <div class="dropdown-menu" aria-labelledby="OurOfferingMenuLink">
#
#                                             <div class="menu-category-items">
#                                                 <ul class="list-inline">
#
#
#     <li>
#         <div class="category-column">
#                 <a href=https://pharma.lonza.com:443/#smallmolecules  data-link-group='Our Offering' data-link-category='Small Molecules' data-link-section='' data-link='Small Molecules'><div class="category-html">
# <div style="background-color:#00b36a;"><img src="/dfsmedia/46777243e1344ddb80f202899ec2ba93/12477-source" /></div>
# <p>We help customers develop, manufacture, and innovate their small molecule medicines through our commitment to science, technology and delivery. We provide integrated drug substance and drug product services through our global site network with a strong track record of being present throughout the product lifecycle.</p>
# </div></a>
#         </div>
#     </li>
#
#
#     <li>
#         <div class="category-column">
#                 <a href=https://pharma.lonza.com:443/#biologics target=_blank data-link-group='Our Offering' data-link-category='Biologics' data-link-section='' data-link='Biologics'><div class="category-html">
# <div style="background-color:#004696;"><img src="/dfsmedia/46777243e1344ddb80f202899ec2ba93/12474-source" /></div>
# <p>In our extensive contract development and manufacturing services portfolio we use advanced technologies to quickly and efficiently deliver products such as monoclonal antibodies, complex proteins and recombinant proteins.</p>
# </div></a>
#         </div>
#     </li>
#
#
#     <li>
#         <div class="category-column">
#                 <a href=https://pharma.lonza.com:443/#cgt  data-link-group='Our Offering' data-link-category='Cell and Gene' data-link-section='' data-link='Cell and Gene'><div class="category-html">
# <div style="background-color:#380577;"><img src="/dfsmedia/46777243e1344ddb80f202899ec2ba93/12475-source" /></div>
# <p>Our Cell &amp; Gene offering spans across development and manufacturing services, products, solutions, testing and automation platforms including the Cocoon®, as well as tools and technologies to develop, de-risk and industrialize therapies from basic research to commercialization.</p>
# </div></a>
#         </div>
#     </li>
#
#
#     <li>
#         <div class="category-column">
#                 <a href=https://pharma.lonza.com:443/#chi  data-link-group='Our Offering' data-link-category='Capsules & Health Ingredients' data-link-section='' data-link='Capsules & Health Ingredients'><div class="category-html">
# <div style="background-color:#c83900;"><img src="/dfsmedia/46777243e1344ddb80f202899ec2ba93/12476-source" /></div>
# <p>Our CHI business offers innovative capsules, dosage form solutions and health ingredients for pharmaceutical and nutraceutical companies.</p>
# </div></a>
#         </div>
#     </li>
#                                                 </ul>
#                                             </div>
#
#                                         </div>
#                                     </li>
#                                     <li class="dropdown dropdown--hoverable allow-focus">
#                                             <span id="AboutUsMenuLink" class="dropdown-toggle" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">About Us</span>
#                                         <div class="dropdown-menu" aria-labelledby="AboutUsMenuLink">
#
#                                             <div class="menu-category-items">
#                                                 <ul class="list-inline">
#
#
#     <li>
#         <div class="category-column-sublist">
#                 <h4>
#                         <a href=/company-overview  data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='Company Overview'>Company Overview</a>
#                 </h4>
#                     <ul class="list-inline" style="">
#                             <li class="">
#                                     <a href=/company-overview/strategy data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='Purpose and Strategy'>Purpose and Strategy</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/company-overview/leadership data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='Leadership'>Leadership</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/company-overview/our-history data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='History'>History</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/company-overview/our-locations data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='Locations'>Locations</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/company-overview/our-websites data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='Websites'>Websites</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/events data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='Events'>Events</a>
#
#                             </li>
#                     </ul>
#         </div>
#     </li>
#
#
#     <li>
#         <div class="category-column-sublist">
#                 <h4>
#                         <a href=/news-and-media  data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='News and Media'>News and Media</a>
#                 </h4>
#                     <ul class="list-inline" style="">
#                             <li class="">
#                                     <a href=/news-and-media/news-archive data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='News Archive'>News Archive</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/news-and-media/image-library data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='Image Library'>Image Library</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/news-and-media/logo-guidelines data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='Logo Guidelines'>Logo Guidelines</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/news-and-media/leadership-portraits data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='Leadership Portraits'>Leadership Portraits</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/news-and-media/videos data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='Videos'>Videos</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/news-and-media/blog data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='Blog'>Blog</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/news-and-media/a-view-on-podcast data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='A View On -  Podcast'>A View On -  Podcast</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/news-and-media/media-inquiries data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='Media Inquiries'>Media Inquiries</a>
#
#                             </li>
#                     </ul>
#         </div>
#     </li>
#
#
#     <li>
#         <div class="category-column-sublist">
#                 <h4>
#                         <a href=/investor-relations  data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Investor Relations'>Investor Relations</a>
#                 </h4>
#                     <ul class="list-inline" style="">
#                             <li class="">
#                                     <a href=/investor-relations/shareholders-and-stock-information data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Shareholder Information'>Shareholder Information</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/investor-relations/agenda-and-events data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Agenda and Events'>Agenda and Events</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/investor-relations/reporting-center data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Financial Reporting'>Financial Reporting</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/investor-relations/corporate-governance data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Corporate Governance'>Corporate Governance</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/sustainability/ethics-and-compliance data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Ethics and Compliance'>Ethics and Compliance</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/investor-relations/contact-investor-relations data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Investor Inquiries'>Investor Inquiries</a>
#
#                             </li>
#                     </ul>
#         </div>
#     </li>
#
#
#     <li>
#         <div class="category-column-sublist">
#                 <h4>
#                         <a href=/sustainability  data-link-group='About Us' data-link-category='Sustainability' data-link-section='' data-link='Sustainability'>Sustainability</a>
#                 </h4>
#                     <ul class="list-inline" style="">
#                             <li class="">
#                                     <a href=/sustainability/performance data-link-group='About Us' data-link-category='Sustainability' data-link-section='' data-link='Performance'>Performance</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/sustainability/people data-link-group='About Us' data-link-category='Sustainability' data-link-section='' data-link='People'>People</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/sustainability/planet data-link-group='About Us' data-link-category='Sustainability' data-link-section='' data-link='Planet'>Planet</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/sustainability/community data-link-group='About Us' data-link-category='Sustainability' data-link-section='' data-link='Community'>Community</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/sustainability/global-quality data-link-group='About Us' data-link-category='Sustainability' data-link-section='' data-link='Global Quality'>Global Quality</a>
#
#                             </li>
#                     </ul>
#         </div>
#     </li>
#                                                 </ul>
#                                             </div>
#
#                                         </div>
#                                     </li>
#                                     <li class="dropdown dropdown--hoverable allow-focus">
#                                             <span id="CareersMenuLink" class="dropdown-toggle" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">Careers</span>
#                                         <div class="dropdown-menu" aria-labelledby="CareersMenuLink">
#
#                                             <div class="menu-category-items">
#                                                 <ul class="list-inline">
#
#
#     <li>
#         <div class="category-column">
#                 <h4>
#                     <a href=/careers  data-link-group='Careers' data-link-category='Overview' data-link-section='' data-link='Overview'>Overview</a>
#                 </h4>
#                 <p>We are here to make a Meaningful Difference. It is the foundation of the way we do business. A career at Lonza is more than a job. We do not just work in the life sciences industries, we are transforming them. What we do today is helping to create a healthier, happier world tomorrow.</p>
#         </div>
#     </li>
#
#
#     <li>
#         <div class="category-column-sublist">
#                 <h4>
#                         <a href=/careers/life-at-lonza  data-link-group='Careers' data-link-category='Life at Lonza' data-link-section='' data-link='Life at Lonza'>Life at Lonza</a>
#                 </h4>
#                     <ul class="list-inline" style="">
#                             <li class="">
#                                     <a href=/careers/life-at-lonza/what-we-offer data-link-group='Careers' data-link-category='Life at Lonza' data-link-section='' data-link='What We Offer'>What We Offer</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/careers/life-at-lonza/career-stories data-link-group='Careers' data-link-category='Life at Lonza' data-link-section='' data-link='Career Stories'>Career Stories</a>
#
#                             </li>
#                     </ul>
#         </div>
#     </li>
#
#
#     <li>
#         <div class="category-column-sublist">
#                 <h4>
#                         <a href=/careers/job-search  data-link-group='Careers' data-link-category='Job Search' data-link-section='' data-link='Job Search'>Job Search</a>
#                 </h4>
#                     <ul class="list-inline" style="">
#                             <li class="">
#                                     <a href=/careers/job-search/recruitment-process data-link-group='Careers' data-link-category='Job Search' data-link-section='' data-link='Recruitment Process'>Recruitment Process</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/careers/job-search/students-graduates-apprentices data-link-group='Careers' data-link-category='Job Search' data-link-section='' data-link='Students, Graduates and Apprentices'>Students, Graduates and Apprentices</a>
#
#                             </li>
#                             <li class="">
#                                     <a href=/careers/job-search/join-us-to-control-coronavirus data-link-group='Careers' data-link-category='Job Search' data-link-section='' data-link='Join Us To Control COVID-19'>Join Us To Control COVID-19</a>
#
#                             </li>
#                     </ul>
#         </div>
#     </li>
#                                                 </ul>
#                                             </div>
#
#                                         </div>
#                                     </li>
#                                     <li>
#                                         <a href="/contact" id="ContactMenuLink" class="" data-link-group='Contact' data-link-category='' data-link-section='' data-link='Contact'>Contact</a>
#                                     </li>
#                         </ul>
#                     </div>
#
#
#                     <div class="dd-search dropdown allow-focus">
#                         <button id="headerSearch-dLabel" class="no-style" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false" data-blur-background>
#                             <i class="fal fa-search"></i>
#                         </button>
#                         <div class="dropdown-menu" aria-labelledby="headerSearch-dLabel">
#                             <div class="header-search-container">
#                                 <div class="container">
#
#                                     <form action="/search-results" method="get">
#                                         <div class="row">
#                                             <div class="col-12">
#                                                 <div class="form-group">
#                                                     <input type="text" name="q" placeholder="Type in your search term..." id="headerSearchQuery" class="form-control" />
#                                                     <input type="submit" class="btn btn-primary" value="Search">
#                                                 </div>
#                                             </div>
#                                         </div>
#                                     </form>
#
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#
#
#
#
#
#                     <div class="dd-hamburg dropdown allow-focus d-lg-none">
#                         <button id="header-dLabel" type="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false" data-blur-background>
#                             <span></span>
#                         </button>
#                         <div class="dropdown-menu" aria-labelledby="header-dLabel">
#
#
#                             <div class="accordion accordion--navigation" id="accordionNav">
#                                     <div class="card">
#                                         <div class="card-header " id="OurOfferingheading" data-toggle="collapse" data-target="#collapseOurOffering" aria-expanded="false" aria-controls="collapseOurOffering" role="button">
#                                                 <h6 class="mb-0">
#                                                     <span>Our Offering</span>
#                                                 </h6>
#
#                                         </div>
#                                         <div id="collapseOurOffering" class="collapse" aria-labelledby="OurOfferingheading" data-parent="#accordionNav">
#                                             <div class="sub-accordion" id="OurOfferingsubAccordion">
#
#                                                     <div class="card">
#                                                         <div class="card-header use-arrow" id="SmallMoleculessubHeading" data-toggle="collapse" data-target="#SmallMoleculessubCollapse" aria-expanded="false" aria-controls="SmallMoleculessubCollapse" role="button">
#                                                                     <a class="sub-arrow" href="https://pharma.lonza.com:443/#smallmolecules" data-link-group='Our Offering' data-link-category='Small Molecules' data-link-section='' data-link='Small Molecules'>
#                                                                         <h6 class="mb-0">
#                                                                             Small Molecules
#                                                                         </h6>
#                                                                     </a>
#
#                                                         </div>
#                                                     </div>
#                                                     <div class="card">
#                                                         <div class="card-header use-arrow" id="BiologicssubHeading" data-toggle="collapse" data-target="#BiologicssubCollapse" aria-expanded="false" aria-controls="BiologicssubCollapse" role="button">
#                                                                     <a class="sub-arrow" href="https://pharma.lonza.com:443/#biologics" data-link-group='Our Offering' data-link-category='Biologics' data-link-section='' data-link='Biologics'>
#                                                                         <h6 class="mb-0">
#                                                                             Biologics
#                                                                         </h6>
#                                                                     </a>
#
#                                                         </div>
#                                                     </div>
#                                                     <div class="card">
#                                                         <div class="card-header use-arrow" id="CellandGenesubHeading" data-toggle="collapse" data-target="#CellandGenesubCollapse" aria-expanded="false" aria-controls="CellandGenesubCollapse" role="button">
#                                                                     <a class="sub-arrow" href="https://pharma.lonza.com:443/#cgt" data-link-group='Our Offering' data-link-category='Cell and Gene' data-link-section='' data-link='Cell and Gene'>
#                                                                         <h6 class="mb-0">
#                                                                             Cell and Gene
#                                                                         </h6>
#                                                                     </a>
#
#                                                         </div>
#                                                     </div>
#                                                     <div class="card">
#                                                         <div class="card-header use-arrow" id="CapsulesandHealthIngredientssubHeading" data-toggle="collapse" data-target="#CapsulesandHealthIngredientssubCollapse" aria-expanded="false" aria-controls="CapsulesandHealthIngredientssubCollapse" role="button">
#                                                                     <a class="sub-arrow" href="https://pharma.lonza.com:443/#chi" data-link-group='Our Offering' data-link-category='Capsules & Health Ingredients' data-link-section='' data-link='Capsules & Health Ingredients'>
#                                                                         <h6 class="mb-0">
#                                                                             Capsules &amp; Health Ingredients
#                                                                         </h6>
#                                                                     </a>
#
#                                                         </div>
#                                                     </div>
#
#                                             </div>
#                                         </div>
#                                     </div>
#                                     <div class="card">
#                                         <div class="card-header " id="AboutUsheading" data-toggle="collapse" data-target="#collapseAboutUs" aria-expanded="false" aria-controls="collapseAboutUs" role="button">
#                                                 <h6 class="mb-0">
#                                                     <span>About Us</span>
#                                                 </h6>
#
#                                         </div>
#                                         <div id="collapseAboutUs" class="collapse" aria-labelledby="AboutUsheading" data-parent="#accordionNav">
#                                             <div class="sub-accordion" id="AboutUssubAccordion">
#
#                                                     <div class="card">
#                                                         <div class="card-header " id="CompanyOverviewsubHeading" data-toggle="collapse" data-target="#CompanyOverviewsubCollapse" aria-expanded="false" aria-controls="CompanyOverviewsubCollapse" role="button">
#                                                                     <h6 class="mb-0">
#                                                                         <a href="/company-overview" data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='Company Overview'>Company Overview</a>
#                                                                     </h6>
#
#                                                         </div>
#                                                             <div id="CompanyOverviewsubCollapse" class="collapse" aria-labelledby="CompanyOverviewsubHeading" data-parent="#AboutUssubAccordion">
#                                                                 <div class="card-body">
#                                                                     <ul class="list-inline">
#                                                                             <li>
#                                                                                 <a href="/company-overview/strategy" data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='Purpose and Strategy'>Purpose and Strategy</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/company-overview/leadership" data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='Leadership'>Leadership</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/company-overview/our-history" data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='History'>History</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/company-overview/our-locations" data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='Locations'>Locations</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/company-overview/our-websites" data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='Websites'>Websites</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/events" data-link-group='About Us' data-link-category='Company Overview' data-link-section='' data-link='Events'>Events</a>
#                                                                             </li>
#                                                                     </ul>
#                                                                 </div>
#                                                             </div>
#                                                     </div>
#                                                     <div class="card">
#                                                         <div class="card-header " id="NewsandMediasubHeading" data-toggle="collapse" data-target="#NewsandMediasubCollapse" aria-expanded="false" aria-controls="NewsandMediasubCollapse" role="button">
#                                                                     <h6 class="mb-0">
#                                                                         <a href="/news-and-media" data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='News and Media'>News and Media</a>
#                                                                     </h6>
#
#                                                         </div>
#                                                             <div id="NewsandMediasubCollapse" class="collapse" aria-labelledby="NewsandMediasubHeading" data-parent="#AboutUssubAccordion">
#                                                                 <div class="card-body">
#                                                                     <ul class="list-inline">
#                                                                             <li>
#                                                                                 <a href="/news-and-media/news-archive" data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='News Archive'>News Archive</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/news-and-media/image-library" data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='Image Library'>Image Library</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/news-and-media/logo-guidelines" data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='Logo Guidelines'>Logo Guidelines</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/news-and-media/leadership-portraits" data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='Leadership Portraits'>Leadership Portraits</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/news-and-media/videos" data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='Videos'>Videos</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/news-and-media/blog" data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='Blog'>Blog</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/news-and-media/a-view-on-podcast" data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='A View On -  Podcast'>A View On -  Podcast</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/news-and-media/media-inquiries" data-link-group='About Us' data-link-category='News and Media' data-link-section='' data-link='Media Inquiries'>Media Inquiries</a>
#                                                                             </li>
#                                                                     </ul>
#                                                                 </div>
#                                                             </div>
#                                                     </div>
#                                                     <div class="card">
#                                                         <div class="card-header " id="InvestorRelationssubHeading" data-toggle="collapse" data-target="#InvestorRelationssubCollapse" aria-expanded="false" aria-controls="InvestorRelationssubCollapse" role="button">
#                                                                     <h6 class="mb-0">
#                                                                         <a href="/investor-relations" data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Investor Relations'>Investor Relations</a>
#                                                                     </h6>
#
#                                                         </div>
#                                                             <div id="InvestorRelationssubCollapse" class="collapse" aria-labelledby="InvestorRelationssubHeading" data-parent="#AboutUssubAccordion">
#                                                                 <div class="card-body">
#                                                                     <ul class="list-inline">
#                                                                             <li>
#                                                                                 <a href="/investor-relations/shareholders-and-stock-information" data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Shareholder Information'>Shareholder Information</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/investor-relations/agenda-and-events" data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Agenda and Events'>Agenda and Events</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/investor-relations/reporting-center" data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Financial Reporting'>Financial Reporting</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/investor-relations/corporate-governance" data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Corporate Governance'>Corporate Governance</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/sustainability/ethics-and-compliance" data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Ethics and Compliance'>Ethics and Compliance</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/investor-relations/contact-investor-relations" data-link-group='About Us' data-link-category='Investor Relations' data-link-section='' data-link='Investor Inquiries'>Investor Inquiries</a>
#                                                                             </li>
#                                                                     </ul>
#                                                                 </div>
#                                                             </div>
#                                                     </div>
#                                                     <div class="card">
#                                                         <div class="card-header " id="SustainabilitysubHeading" data-toggle="collapse" data-target="#SustainabilitysubCollapse" aria-expanded="false" aria-controls="SustainabilitysubCollapse" role="button">
#                                                                     <h6 class="mb-0">
#                                                                         <a href="/sustainability" data-link-group='About Us' data-link-category='Sustainability' data-link-section='' data-link='Sustainability'>Sustainability</a>
#                                                                     </h6>
#
#                                                         </div>
#                                                             <div id="SustainabilitysubCollapse" class="collapse" aria-labelledby="SustainabilitysubHeading" data-parent="#AboutUssubAccordion">
#                                                                 <div class="card-body">
#                                                                     <ul class="list-inline">
#                                                                             <li>
#                                                                                 <a href="/sustainability/performance" data-link-group='About Us' data-link-category='Sustainability' data-link-section='' data-link='Performance'>Performance</a>
#                                                                             </li>
#                                                                             <li>
#                                                                                 <a href="/sustainability/people" data-link-group='About Us' data-link-category='Sustainability' data-link-section='' data-link='People'>People</a>
#                                                                             </li>
#                                                                             <li>
# ...
#                                     <div class="content">
#                                         <div class="row">
#                                             <div class="col">
#                                             </div>
#                                             <div class="col text-right">
#                                                 <label>
#                                                 </label>
#                                             </div>
#                                         </div>
#                                         <h5>Careers in Guangzhou (CN)</h5>
#                                         <div class="text flex-grow">Learn more about career opportunities in Guangzhou, China</div>
#                                         <div class="link-type-internal">
#                                                 <a href="/careers/job-search/careers-in-guangzhou" class="btn btn-primary " data-title="Careers in Guangzhou (CN)" data-gated-form="" data-content-type="">Learn more</a>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </div>
#                             <div class="col-md mb-3">
#                                 <div class="feature-card " style="">
#                                     <div class="content">
#                                         <div class="row">
#                                             <div class="col">
#                                             </div>
#                                             <div class="col text-right">
#                                                 <label>
#                                                 </label>
#                                             </div>
#                                         </div>
#                                         <h5>Careers in Drug Product Services</h5>
#                                         <div class="text flex-grow">Learn more about career opportunities in Drug Product Services</div>
#                                         <div class="link-type-internal">
#                                                 <a href="/careers/job-search/careers-in-dps" class="btn btn-primary " data-title="Careers in Drug Product Services" data-gated-form="" data-content-type="">Learn more</a>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </div>
#                             <div class="col-md mb-3">
#                                 <div class="feature-card " style="">
#                                     <div class="content">
#                                         <div class="row">
#                                             <div class="col">
#                                             </div>
#                                             <div class="col text-right">
#                                                 <label>
#                                                 </label>
#                                             </div>
#                                         </div>
#                                         <h5>Join us to control COVID-19</h5>
#                                         <div class="text flex-grow">Every day, our employees are working to create a healthier world.</div>
#                                         <div class="link-type-internal">
#                                                 <a href="/careers/job-search/join-us-to-control-coronavirus" class="btn btn-primary " data-title="Join us to control COVID-19" data-gated-form="" data-content-type="">Learn more</a>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </div>
#             </div>
#         </div>
# </section>
#
# <div class="vertical-spacer"></div>
#
#
#         </main>
#         <div id="overlay--main"></div>
#     </div>
#     <div id="modal" class="mfp-hide">
#
#     </div>
#     <footer id="footer" class="bg-black">
#
#
#
#     <div class="container-fluid container-fluid--max">
#         <div class="footer-inner position-relative text-center text-md-left">
#             <div class="row">
#                 <div class="logo-container col-12 col-lg-3">
# <?xml version="1.0" encoding="utf-8" ?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="155" height="28">
# 	<defs>
# 		<clipPath id="clip_0">
# 			<rect x="-150" y="-249" width="2380" height="1029" clip-rule="evenodd"/>
# 		</clipPath>
# 	</defs>
# 	<g clip-path="url(#clip_0)">
# 		<path fill="rgb(255,255,255)" stroke="none" d="M0 26.7826L0 0L10.2775 0L10.2775 18.5884L24.2188 18.5884L24.2188 26.7826L0 26.7826ZM25.4297 14.0253C25.4297 5.09103 32.8126 0 41.1719 0C49.5325 0 56.9141 5.09103 56.9141 14.0253C56.9141 22.9581 49.4806 28 41.1719 28C32.8632 28 25.4297 22.9581 25.4297 14.0253ZM146.007 3.30603L146.007 0.617107L155 0.617107L155 27.1985L146.007 27.1985L146.007 24.4804L145.878 24.651C143.825 27.4189 140.597 28 138.25 28C130.541 28 124.727 21.9704 124.727 13.9743C124.727 9.76831 126.048 6.1461 128.447 3.77475C130.91 1.34099 134.356 0 138.149 0C140.925 0 144.078 1.18706 145.883 3.17013L146.007 3.30603ZM69.6808 4.1215C71.4551 1.4129 74.4876 0.0455988 77.3173 0.00180125C84.3242 -0.103586 89.6094 4.42261 89.6094 11.7204L89.6094 26.7826L80.4836 26.7826L80.4755 14.3975C80.4755 10.4407 78.8025 8.47114 75.6011 8.18783C73.5997 8.01127 69.6618 9.1678 69.6808 13.8979L69.6808 26.7826L60.5469 26.7826L60.5469 0.729935L69.6808 0.729935L69.6808 4.1215ZM123.516 1.21739L123.428 1.33026C123.006 1.8704 113.831 13.8515 110.752 17.912C110.752 17.912 109.741 19.2449 109.716 19.2798L122.545 19.2798L122.545 26.7826L93.2422 26.7826L93.3299 26.6724C93.8298 26.0302 106.825 9.1757 107.376 8.45686C107.376 8.45686 107.41 8.42327 107.435 8.39774L94.6946 8.39774L94.6946 1.21739L123.516 1.21739ZM35.1172 14C35.1172 17.7489 38.0467 20.6957 41.7773 20.6957C45.5094 20.6957 48.4375 17.7489 48.4375 14C48.4375 10.2497 45.5094 7.30435 41.7773 7.30435C38.0467 7.30435 35.1172 10.2497 35.1172 14ZM141.182 20.6957C137.45 20.6957 134.414 17.6905 134.414 14C134.414 10.308 137.45 7.30435 141.182 7.30435C144.915 7.30435 147.734 10.308 147.734 14C147.734 17.6905 144.915 20.6957 141.182 20.6957Z" fill-rule="evenodd"/>
# 	</g>
# </svg>
#                 </div>
#
#                 <div class="footer-links-container col-12 col-lg">
#                     <div class="row">
#                             <section class="col-12 col-md">
#                                 <h3>
#
# Our Offering
#                                 </h3>
#                                 <ul class="list-inline">
#                                             <li>
# <a href="https://pharma.lonza.com/" target="_blank" rel="noopener noreferrer" >Pharma &amp; Biotech</a>                                            </li>
#                                             <li>
# <a href="#consumerhealth" >Capsules &amp; Health Ingredients</a>                                            </li>
#                                 </ul>
#                             </section>
#                             <section class="col-12 col-md">
#                                 <h3>
#
# About Us
#                                 </h3>
#                                 <ul class="list-inline">
#                                             <li>
# <a href="/company-overview" >Company</a>                                            </li>
#                                             <li>
# <a href="/news-and-media" >News and Media</a>                                            </li>
#                                             <li>
# <a href="/investor-relations" >Investor Relations</a>                                            </li>
#                                             <li>
# <a href="/sustainability" >Sustainability</a>                                            </li>
#                                             <li>
# <a href="/events" >Events</a>                                            </li>
#                                 </ul>
#                             </section>
#                             <section class="col-12 col-md">
#                                 <h3>
#
# Careers
#                                 </h3>
#                                 <ul class="list-inline">
#                                             <li>
# <a href="/careers" >Overview</a>                                            </li>
#                                             <li>
# <a href="/careers/life-at-lonza" >Life at Lonza</a>                                            </li>
#                                             <li>
# <a href="/careers/life-at-lonza/career-stories" >Career Stories</a>                                            </li>
#                                             <li>
# <a href="/careers/job-search" >Apply</a>                                            </li>
#                                 </ul>
#                             </section>
#                             <section class="col-12 col-md">
#                                 <h3>
#
# Utilities
#                                 </h3>
#                                 <ul class="list-inline">
#                                             <li>
# <a href="/contact" >Contact</a>                                            </li>
#                                             <li>
# <a href="/policy/legal-disclaimer" >Legal Disclaimer</a>                                            </li>
#                                             <li>
# <a href="/policy/privacy-policy" >Privacy Policy</a>                                            </li>
#                                             <li>
# <a href="/sitemap" >Sitemap</a>                                            </li>
#                                 </ul>
#                             </section>
#                     </div>
#                 </div>
#             </div>
#             <div class="row align-items-center flex-lg-row-reverse">
#                 <div class="footer-social-container col-12 col-lg-5">
#                     <ul class="list-inline">
#                             <li class="list-inline-item">
#                                 <a href="https://www.facebook.com/LonzaGroupAG/"><i class="icon fab fa-facebook-f fa-lg"></i></a>
#                             </li>
#                                                     <li class="list-inline-item">
#                                 <a href="https://twitter.com/lonzagroup"><i class="icon fab fa-twitter fa-lg"></i></a>
#                             </li>
#                                                     <li class="list-inline-item">
#                                 <a href="https://www.instagram.com/lonzagroup/"><i class="icon fab fa-instagram fa-lg"></i></a>
#                             </li>
#                                                     <li class="list-inline-item">
#                                 <a href="https://www.linkedin.com/company/lonza"><i class="icon fab fa-linkedin-in fa-lg"></i></a>
#                             </li>
#                                                                             <li class="list-inline-item">
#                                 <a href="https://www.youtube.com/channel/UCszBjcMWTTGwlNzqTPJ_FUg"><i class="icon fab fa-youtube fa-lg"></i></a>
#                             </li>
#                     </ul>
#                 </div>
#                 <div class="footer-copyright-container col-12 col-lg">
#                     <span>&copy; 2021 Lonza. All rights reserved.</span>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     </footer>
#
#     <!-- External Javascript Libraries -->
#     <script type="text/javascript" src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.1/js/bootstrap.bundle.min.js" async></script>
#     <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.js" async></script>
#     <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/magnific-popup.js/1.1.0/jquery.magnific-popup.min.js"></script>
#     <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.8.1/slick.min.js"></script>
#     <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-select/1.12.4/js/bootstrap-select.min.js"></script>
#
# <!-- inject:js -->
# <link rel="preload" href="/Assets/lonza/js/lonza.a0cd24d161ae650bd705696bec4471970985e783.js" as="script"/><script src="/Assets/lonza/js/lonza.a0cd24d161ae650bd705696bec4471970985e783.js"></script>
# <!-- endinject -->
#     <script type='text/javascript' src='//platform-api.sharethis.com/js/sharethis.js#property=5d25f7c2aca1ef0012990adf&product=inline-share-buttons' async='async'></script>
#
# <script>
# // addeds the customization div for the sharethis buttons
# (function($) {
#   // use to add a msg before the hyperlink in the email share
#   var msg = "";
#   // the utm tags
#   var utmparms = "utm_source=email-share&utm_medium=email&utm_campaign=shared-from-website";
#   // checks to see whether use to add a '?' or "&" before the utm tags
#   var utmper = "&";
#   if ($(location).attr('href').indexOf("?") <= 0) utmper = "?";
#   // Combine the URL with the tum prefix and utm tags
#   var URL = $(location).attr('href') + utmper  + utmparms ;
#   //creates the customization div
#   $("body").append('</br> <div class="sharethis-sticky-share-buttons" data-url="' + $(location).attr('href') +'" data-message= "'+ msg + URL +'"></div>');
# })(jQuery);;
# </script>
#
#     <!-- Magnific Popup -->
#     <script type="text/javascript" src="/Assets/lonza/libs/magnific-popup/magnific-popup.js"></script>
#     <link href="/Assets/lonza/libs/magnific-popup/magnific-popup.scss" type="text/css" />
#
# <style type="text/css">
#   .dialog { position: relative; background: #FFF; padding: 20px; width: auto; max-width: 60%; margin: 20px auto; }
# </style>
#
# <script type="text/javascript">
#   (function($){
#     var _a = [];
#     _a.push('<div id="consumerhealth" class="dialog mfp-hide"><div class="row" style="text-align:center;">');
#     _a.push('<div class="col"><p>Looking for our Capsule Solutions?</p><a class="btn btn-primary external" href="https://www.capsugel.com/?utm_source=lonza">Visit site</a></div>');
#     _a.push('<div class="col"><p>Looking for our Health Ingredients?</p><a class="btn btn-primary external" href="https://www.capsugel.com/product-suites/specialty-ingredients">Visit site</a></div>');
#     _a.push('</div></div>');
#     $('body').append(_a.join(''));
#     $('a[href="#consumerhealth"]').magnificPopup({items:{ src: '#consumerhealth', type: 'inline' }});
#   })(jQuery);
# </script>
#
# <script type="text/javascript">
#   (function($){
# 	$('[data-brightcove]').each(function(i){
# 	  var t = $(this), bc = t.attr('data-brightcove'), exp = t.attr('data-experience');
# 	  document.write('<script src="https://players.brightcove.net/'+bc+'/experience_'+exp+'/live.js"></scr'+'ipt>');
# 	});
#   })(jQuery);
# </script>
#
# <div id="consent-banner"></div>
# <div id="teconsent">
#   <script type="text/javascript" async="async" src="https://consent.trustarc.com/v2/notice/smmdm2"></script>
# </div>
#
#
#     <script>
#         window.Lonza = window.Lonza || {};
#
#         // outdated browser plugin call
#         //event listener for DOM ready
#         function addLoadEvent(func) {
#             var oldonload = window.onload;
#             if (typeof window.onload != 'function') {
#                 window.onload = func;
#             } else {
#                 window.onload = function () {
#                     if (oldonload) {
#                         oldonload();
#                     }
#                     func();
#                 }
#             }
#         }
#
#         //call function after DOM ready
#         addLoadEvent(function () {
#             outdatedBrowser({
#                 bgColor: '#f25648',
#                 color: '#ffffff',
#                 lowerThan: 'transform',
#                 languagePath: '../outdatedbrowser/lang/en.html'
#             })
#         });
#     </script>
#
# </body>
# </html>

# %%
# PARSEO DEL ARBOL HTML QUE RECIBO COMO RESPUESTA CON LXML
parser = html.fromstring(respuesta.text)

# %%
# PARSEP DE TODOS LOS PUESTOS POR CLASE
list_puestos = parser.find_class('search-result-title')

for puesto in list_puestos:
    text_puesto = puesto.text_content()
    print(text_puesto)

len(list_puestos)
# Out:
# Intern Forensic Chemistry
# Student Internship / Praktikant
# (Senior) Scientist Process Development
# Senior Data Engineer
# Data Governance Manager
# Functional Specialist - Data Coordinator
# (Senior) Scientist Physico-Chemical Quality Control
# Scientist Bioanalytics
# Head of Process Development LNP
# Team Leader, Physico-Chemical Quality Control
# Principal Scientist / Group Lead Physico-Chemical Quality Control
# Technology Transfer Lead
# (Senior) Scientist Stability Physico-Chemical Quality Control
# Scientist Formulation Development
# Lead Scientist, Formulation Development, DPS
# Director Commercial Development (Mammalian)
# Head Commercial Quality Control Drug Product Services
# Technical Proposals Manager, Drug Product Services
# QC Planner/Scheduler (m/f/d)
# Lead Scientist, Process Development
# Quality Network Head Drug Product Services
# QC Lab Systems Specialist
# Technical Sales Manager
# Head of Physico-Chemical Quality Control Drug Product Services
# Senior Principal Scientist / Group Head Bioanalytics
# Program Manager DPS
# Internship Marketing - Business Intelligence and Analytics 100%
# Integration Engineer
# Integration Architect
# Intern Supply Chain and Vendor Supply Chain Integrity (100%)
# Digital HR Reporting & Insights Specialist
# Associate Director, Digital Portfolio Testing & Release
# Global Head of MSAT - Technical Transfer & Processes (m/f/d)
# Principal Scientist / Group Lead Formulation Development
# Associate Principal Scientist, DP Process Development
# Sales & Operations – CoE Specialist (m/f/d)
# IT Strategy Development & Team Lead
# •	Internal Auditor/ Audit Manager (with finance/accounting expertise)
# Strategic Growth Project Lead
# Scientist Forensic Chemistry
# Quality Assurance Expert QC Analytics
# Intern – Global Warehouse Strategy (100%)
# Business Analyst Digital
# Transport Excellence Director (m/f/w)
# Head of Sales and Business Development EMEA and APAC
# Principal / Associate Principal Scientist - Analytical Project Leader
# Demand Planning – CoE Specialist (m/f/d)
# Trade Compliance Manager
# IT Auditor / IT Audit Manager
# Regional Employer Brand Lead, EMEA
# 50

# %%
# PARSEO DE TODOS LOS REGIONS AND COUNTRIES POR CLASE
list_countries = parser.find_class('search-result-content')

for country in list_countries:
    text_country = country.text_content()
    print(text_country)

len(list_countries)
# Out:
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel; Switzerland, Visp
# Switzerland, Basel
# Switzerland, Basel; United States, Portsmouth (New Hampshire)
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel; United Kingdom, Slough
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel; Switzerland, Visp
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel; Switzerland, Visp
# Switzerland, Basel; Switzerland, Visp
# Switzerland, Basel; Switzerland, Stein
# Switzerland, Basel; United Kingdom, Manchester
# Singapore, Singapore; Singapore, Tuas Singapore; Spain, Porrino; Switzerland, Basel; Switzerland, Visp; United Kingdom, Slough; United States, Portsmouth (New Hampshire)
# Switzerland, Basel; Switzerland, Visp; United States, Portsmouth (New Hampshire)
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel; Switzerland, Visp
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel; United Kingdom, Manchester
# 50

# %%
# CONVERTIMOS LOS ELEMENTOS LXML EN STR PARA PODER MANIPULAR LAS LISTAS

list_text_puestos = []
list_text_countries = []

for puesto in list_puestos:
    
    text_puesto = str(puesto.text_content()) # UTILIZO EL METODO TEXT_CONTENT() PARA TRAER DIRECTAMENTE EL TEXTO
    list_text_puestos.append(text_puesto)
    
for country in list_countries:
    
    text_country = str(country.text_content())
    list_text_countries.append(text_country)
             
print(list_text_puestos, len(list_text_puestos), type(list_text_puestos[0]))
print()
print()
print(list_text_countries, len(list_text_countries), type(list_text_countries[0]))
# Out:
# ['Intern Forensic Chemistry', 'Student Internship / Praktikant', '(Senior) Scientist Process Development', 'Senior Data Engineer', 'Data Governance Manager', 'Functional Specialist - Data Coordinator', '(Senior) Scientist Physico-Chemical Quality Control', 'Scientist Bioanalytics', 'Head of Process Development LNP', 'Team Leader, Physico-Chemical Quality Control', 'Principal Scientist / Group Lead Physico-Chemical Quality Control', 'Technology Transfer Lead', '(Senior) Scientist Stability Physico-Chemical Quality Control', 'Scientist Formulation Development', 'Lead Scientist, Formulation Development, DPS', 'Director Commercial Development (Mammalian)', 'Head Commercial Quality Control Drug Product Services', 'Technical Proposals Manager, Drug Product Services', 'QC Planner/Scheduler (m/f/d)', 'Lead Scientist, Process Development', 'Quality Network Head Drug Product Services', 'QC Lab Systems Specialist', 'Technical Sales Manager', 'Head of Physico-Chemical Quality Control Drug Product Services', 'Senior Principal Scientist / Group Head Bioanalytics', 'Program Manager DPS', 'Internship Marketing - Business Intelligence and Analytics 100%', 'Integration Engineer', 'Integration Architect', 'Intern Supply Chain and Vendor Supply Chain Integrity (100%)', 'Digital HR Reporting & Insights Specialist', 'Associate Director, Digital Portfolio Testing & Release', 'Global Head of MSAT - Technical Transfer & Processes (m/f/d)', 'Principal Scientist / Group Lead Formulation Development', 'Associate Principal Scientist, DP Process Development', 'Sales & Operations – CoE Specialist (m/f/d)', 'IT Strategy Development & Team Lead', '•\tInternal Auditor/ Audit Manager (with finance/accounting expertise)', 'Strategic Growth Project Lead', 'Scientist Forensic Chemistry', 'Quality Assurance Expert QC Analytics', 'Intern – Global Warehouse Strategy (100%)', 'Business Analyst Digital', 'Transport Excellence Director (m/f/w)', 'Head of Sales and Business Development EMEA and APAC', 'Principal / Associate Principal Scientist - Analytical Project Leader', 'Demand Planning – CoE Specialist (m/f/d)', 'Trade Compliance Manager', 'IT Auditor / IT Audit Manager', 'Regional Employer Brand Lead, EMEA'] 50 <class 'str'>
#
#
# ['Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel; Switzerland, Visp', 'Switzerland, Basel', 'Switzerland, Basel; United States, Portsmouth (New Hampshire)', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel; United Kingdom, Slough', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel; Switzerland, Visp', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel; Switzerland, Visp', 'Switzerland, Basel; Switzerland, Visp', 'Switzerland, Basel; Switzerland, Stein', 'Switzerland, Basel; United Kingdom, Manchester', 'Singapore, Singapore; Singapore, Tuas Singapore; Spain, Porrino; Switzerland, Basel; Switzerland, Visp; United Kingdom, Slough; United States, Portsmouth (New Hampshire)', 'Switzerland, Basel; Switzerland, Visp; United States, Portsmouth (New Hampshire)', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel; Switzerland, Visp', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel', 'Switzerland, Basel; United Kingdom, Manchester'] 50 <class 'str'>

# %%
for (i) in range(len(list_text_puestos)):
    print("Puesto: ", list_text_puestos[i], "\n",  "Country: ", list_text_countries[i])
    print()
# Out:
# Puesto:  Intern Forensic Chemistry
#  Country:  Switzerland, Basel
#
# Puesto:  Student Internship / Praktikant
#  Country:  Switzerland, Basel
#
# Puesto:  (Senior) Scientist Process Development
#  Country:  Switzerland, Basel
#
# Puesto:  Senior Data Engineer
#  Country:  Switzerland, Basel; Switzerland, Visp
#
# Puesto:  Data Governance Manager
#  Country:  Switzerland, Basel
#
# Puesto:  Functional Specialist - Data Coordinator
#  Country:  Switzerland, Basel; United States, Portsmouth (New Hampshire)
#
# Puesto:  (Senior) Scientist Physico-Chemical Quality Control
#  Country:  Switzerland, Basel
#
# Puesto:  Scientist Bioanalytics
#  Country:  Switzerland, Basel
#
# Puesto:  Head of Process Development LNP
#  Country:  Switzerland, Basel
#
# Puesto:  Team Leader, Physico-Chemical Quality Control
#  Country:  Switzerland, Basel
#
# Puesto:  Principal Scientist / Group Lead Physico-Chemical Quality Control
#  Country:  Switzerland, Basel
#
# Puesto:  Technology Transfer Lead
#  Country:  Switzerland, Basel
#
# Puesto:  (Senior) Scientist Stability Physico-Chemical Quality Control
#  Country:  Switzerland, Basel
#
# Puesto:  Scientist Formulation Development
#  Country:  Switzerland, Basel
#
# Puesto:  Lead Scientist, Formulation Development, DPS
#  Country:  Switzerland, Basel
#
# Puesto:  Director Commercial Development (Mammalian)
#  Country:  Switzerland, Basel; United Kingdom, Slough
#
# Puesto:  Head Commercial Quality Control Drug Product Services
#  Country:  Switzerland, Basel
#
# Puesto:  Technical Proposals Manager, Drug Product Services
#  Country:  Switzerland, Basel
#
# Puesto:  QC Planner/Scheduler (m/f/d)
#  Country:  Switzerland, Basel
#
# Puesto:  Lead Scientist, Process Development
#  Country:  Switzerland, Basel
#
# Puesto:  Quality Network Head Drug Product Services
#  Country:  Switzerland, Basel
#
# Puesto:  QC Lab Systems Specialist
#  Country:  Switzerland, Basel
#
# Puesto:  Technical Sales Manager
#  Country:  Switzerland, Basel; Switzerland, Visp
#
# Puesto:  Head of Physico-Chemical Quality Control Drug Product Services
#  Country:  Switzerland, Basel
#
# Puesto:  Senior Principal Scientist / Group Head Bioanalytics
#  Country:  Switzerland, Basel
#
# Puesto:  Program Manager DPS
#  Country:  Switzerland, Basel
#
# Puesto:  Internship Marketing - Business Intelligence and Analytics 100%
#  Country:  Switzerland, Basel
#
# Puesto:  Integration Engineer
#  Country:  Switzerland, Basel; Switzerland, Visp
#
# Puesto:  Integration Architect
#  Country:  Switzerland, Basel; Switzerland, Visp
#
# Puesto:  Intern Supply Chain and Vendor Supply Chain Integrity (100%)
#  Country:  Switzerland, Basel; Switzerland, Stein
#
# Puesto:  Digital HR Reporting & Insights Specialist
#  Country:  Switzerland, Basel; United Kingdom, Manchester
#
# Puesto:  Associate Director, Digital Portfolio Testing & Release
#  Country:  Singapore, Singapore; Singapore, Tuas Singapore; Spain, Porrino; Switzerland, Basel; Switzerland, Visp; United Kingdom, Slough; United States, Portsmouth (New Hampshire)
#
# Puesto:  Global Head of MSAT - Technical Transfer & Processes (m/f/d)
#  Country:  Switzerland, Basel; Switzerland, Visp; United States, Portsmouth (New Hampshire)
#
# Puesto:  Principal Scientist / Group Lead Formulation Development
#  Country:  Switzerland, Basel
#
# Puesto:  Associate Principal Scientist, DP Process Development
#  Country:  Switzerland, Basel
#
# Puesto:  Sales & Operations – CoE Specialist (m/f/d)
#  Country:  Switzerland, Basel
#
# Puesto:  IT Strategy Development & Team Lead
#  Country:  Switzerland, Basel
#
# Puesto:  •	Internal Auditor/ Audit Manager (with finance/accounting expertise)
#  Country:  Switzerland, Basel
#
# Puesto:  Strategic Growth Project Lead
#  Country:  Switzerland, Basel
#
# Puesto:  Scientist Forensic Chemistry
#  Country:  Switzerland, Basel
#
# Puesto:  Quality Assurance Expert QC Analytics
#  Country:  Switzerland, Basel
#
# Puesto:  Intern – Global Warehouse Strategy (100%)
#  Country:  Switzerland, Basel
#
# Puesto:  Business Analyst Digital
#  Country:  Switzerland, Basel; Switzerland, Visp
#
# Puesto:  Transport Excellence Director (m/f/w)
#  Country:  Switzerland, Basel
#
# Puesto:  Head of Sales and Business Development EMEA and APAC
#  Country:  Switzerland, Basel
#
# Puesto:  Principal / Associate Principal Scientist - Analytical Project Leader
#  Country:  Switzerland, Basel
#
# Puesto:  Demand Planning – CoE Specialist (m/f/d)
#  Country:  Switzerland, Basel
#
# Puesto:  Trade Compliance Manager
#  Country:  Switzerland, Basel
#
# Puesto:  IT Auditor / IT Audit Manager
#  Country:  Switzerland, Basel
#
# Puesto:  Regional Employer Brand Lead, EMEA
#  Country:  Switzerland, Basel; United Kingdom, Manchester

# %%
# PARSEO DE TODOS LOS DESCRIPCIONES
list_descripciones = parser.find_class('col-md-8')

type(list_descripciones)
len(list_descripciones)
# Out:
# 0

# %%
# CREAMOS LISTAS CON LOS DATOS RECOPILADOS
r_countries = parser.find_class('search-result-content')

for r_country in r_countries:
    
    list_r_countries = []
    list_r_countries.append(r_country)
    
    
    


type(list_r_country)
print(list_r_countries , len(list_r_countries))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_36984/1835147685.py in <module>
#      11
#      12
# ---> 13 type(list_r_country)
#      14 print(list_r_countries , len(list_r_countries))
#
# NameError: name 'list_r_country' is not defined
