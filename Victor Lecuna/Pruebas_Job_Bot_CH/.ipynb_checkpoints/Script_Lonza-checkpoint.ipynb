# %% [markdown]
# # Test de extraccion de datos
# ## Utilizare como prueba la pagina Lonza: https://www.lonza.com/careers/job-search para la extraccion de los datos.
#
# Definimos nuestra URL seed aplicando los criterios de filtrado:
# Seed: https://www.lonza.com/careers/job-search?q=data,%20biotech,%20Biostatistics,%20%20clinical%20research&pg=1&rows=100&job_location_facet_sm=Switzerland%2c+Basel

# %%
# IMPORTAMOS LAS LIBRERIAS QUE VAMOS UTILIZAR

from lxml import html
import requests
import pandas as pd
import scrapy
import datetime
import os # PARA CREAR EL DIRECTORIO

# %%
# USER AGENT PARA PROTEGERNOS DE BANEOS
headers = {
    "user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/71.0.3578.80 Chrome/71.0.3578.80 Safari/537.36",
}

# %%
# URL SEED
seed = "https://www.lonza.com/careers/job-search?q=data,%20biotech,%20Biostatistics,%20%20clinical%20research&pg=1&rows=100&job_location_facet_sm=Switzerland%2c+Basel"

# %%
# REQUERIMIENTO AL SERVIDOR
respuesta = requests.get(seed, headers=headers)

# %%
respuesta
# Out:
# <Response [200]>

# %%
# PARSEO DEL ARBOL HTML QUE RECIBO COMO RESPUESTA CON LXML
parser = html.fromstring(respuesta.text)

# %%
# PARSEO DE TODOS LOS PUESTOS POR CLASE
list_job_names = parser.find_class('search-result-title')

for job_name in list_job_names:
    text_job_name = job_name.text_content()
    print(text_job_name)

len(list_job_names)
# Out:
# Student Internship / Praktikant
# (Senior) Scientist Process Development
# Senior Data Engineer
# (Senior) Scientist Physico-Chemical Quality Control
# Scientist Bioanalytics
# Data Governance Manager
# Internship – Strategy Consultant CIO Office
# Head of Process Development LNP
# Team Leader, Physico-Chemical Quality Control
# Technology Transfer Lead
# Lead Scientist, Formulation Development, DPS
# (Senior) Scientist Stability Physico-Chemical Quality Control
# Scientist Formulation Development
# Director Commercial Development (Mammalian)
# Technical Proposals Manager, Drug Product Services
# QC Planner/Scheduler (m/f/d)
# Lead Scientist, Process Development
# Quality Network Head Drug Product Services
# QC Lab Systems Specialist
# Technical Sales Manager
# Lead Scientist, Physico-Chemical Quality Control
# Program Manager DPS
# Head of Physico-Chemical Quality Control Drug Product Services
# Senior Program Manager Drug Product Services
# Senior Principal Scientist / Group Head Bioanalytics
# Capital Projects Specialist
# Integration Engineer
# Integration Architect
# Associate Director, Digital Portfolio Testing & Release
# Principal Scientist / Group Lead Formulation Development
# Digital HR Reporting & Insights Specialist
# Digital HR Security Lead
# Sales & Operations – CoE Specialist (m/f/d)
# IT Strategy Development & Team Lead
# •	Internal Auditor/ Audit Manager (with finance/accounting expertise)
# Strategic Growth Project Lead
# Strategic Growth Project Lead (f/m/d)
# Scientist Forensic Chemistry
# Transport Excellence Director (m/f/w)
# Business Analyst Digital
# Intern – Global Warehouse Strategy (100%)
# Global Head of Finance Commercial CHI
# Principal / Associate Principal Scientist - Analytical Project Leader
# Demand Planning – CoE Specialist (m/f/d)
# Trade Compliance Manager
# Regional Employer Brand Lead, EMEA
# Head Supply Chain Drug Product Services
# 47

# %%
# PARSEO DE TODOS LOS LOCATIONS POR CLASE
list_locations = parser.find_class('search-result-content')

for location in list_locations:
    text_location = location.text_content()
    print(text_location)

len(list_locations)
# Out:
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel; Switzerland, Visp
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel; United Kingdom, Slough
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel; Switzerland, Visp
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel; United States, Portsmouth (New Hampshire)
# Switzerland, Basel; Switzerland, Visp
# Switzerland, Basel; Switzerland, Visp
# Singapore, Singapore; Singapore, Tuas Singapore; Spain, Porrino; Switzerland, Basel; Switzerland, Visp; United Kingdom, Slough; United States, Portsmouth (New Hampshire)
# Switzerland, Basel
# Switzerland, Basel; United Kingdom, Manchester
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel; Switzerland, Stein
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel; Switzerland, Visp
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel
# Switzerland, Basel; United Kingdom, Manchester
# Switzerland, Basel
# 47

# %%
# CONVERTIMOS LOS ELEMENTOS LXML EN STR PARA PODER MANIPULAR LAS LISTAS

list_str_job_names = []
list_str_locations = []

for job_name in list_job_names:
    str_job_name = str(job_name.text_content()) # UTILIZO EL METODO TEXT_CONTENT() PARA TRAER DIRECTAMENTE EL TEXTO
    list_str_job_names.append(str_job_name)

for location in list_locations:
    str_location = str(job_name.text_content()) 
    list_str_locations.append(str_location)
    
    

print(list_str_job_names, len(list_str_job_names))
print()
print(list_str_locations, len(list_str_locations))
# Out:
# ['Student Internship / Praktikant', '(Senior) Scientist Process Development', 'Senior Data Engineer', '(Senior) Scientist Physico-Chemical Quality Control', 'Scientist Bioanalytics', 'Data Governance Manager', 'Internship – Strategy Consultant CIO Office', 'Head of Process Development LNP', 'Team Leader, Physico-Chemical Quality Control', 'Technology Transfer Lead', 'Lead Scientist, Formulation Development, DPS', '(Senior) Scientist Stability Physico-Chemical Quality Control', 'Scientist Formulation Development', 'Director Commercial Development (Mammalian)', 'Technical Proposals Manager, Drug Product Services', 'QC Planner/Scheduler (m/f/d)', 'Lead Scientist, Process Development', 'Quality Network Head Drug Product Services', 'QC Lab Systems Specialist', 'Technical Sales Manager', 'Lead Scientist, Physico-Chemical Quality Control', 'Program Manager DPS', 'Head of Physico-Chemical Quality Control Drug Product Services', 'Senior Program Manager Drug Product Services', 'Senior Principal Scientist / Group Head Bioanalytics', 'Capital Projects Specialist', 'Integration Engineer', 'Integration Architect', 'Associate Director, Digital Portfolio Testing & Release', 'Principal Scientist / Group Lead Formulation Development', 'Digital HR Reporting & Insights Specialist', 'Digital HR Security Lead', 'Sales & Operations – CoE Specialist (m/f/d)', 'IT Strategy Development & Team Lead', '•\tInternal Auditor/ Audit Manager (with finance/accounting expertise)', 'Strateg
# 47

# %%
# CREANDO VARIABLE DE FECHA

date = datetime.date.today()
date
# Out:
# datetime.date(2021, 10, 13)

# %%
# CREANDO DATAFRAME CON LOS DATOS RECOPILADOS

lonza_dataframe = pd.DataFrame(data = { "Company": "LONZA",
                                       "Data_Time": date,
                                       "Job_Name": list_str_job_names,
                                       "Location": list_str_locations,
                                       "Links": list_str_links})
lonza_dataframe
# Out:
#    Company   Data_Time                                           Job_Name  \
# 0    LONZA  2021-10-13                    Student Internship / Praktikant
# 1    LONZA  2021-10-13             (Senior) Scientist Process Development
# 2    LONZA  2021-10-13                               Senior Data Engineer
# 3    LONZA  2021-10-13  (Senior) Scientist Physico-Chemical Quality Co...
# 4    LONZA  2021-10-13                             Scientist Bioanalytics
# 5    LONZA  2021-10-13                            Data Governance Manager
# 6    LONZA  2021-10-13        Internship – Strategy Consultant CIO Office
# 7    LONZA  2021-10-13                    Head of Process Development LNP
# 8    LONZA  2021-10-13      Team Leader, Physico-Chemical Quality Control
# 9    LONZA  2021-10-13                           Technology Transfer Lead
# 10   LONZA  2021-10-13       Lead Scientist, Formulation Development, DPS
# 11   LONZA  2021-10-13  (Senior) Scientist Stability Physico-Chemical ...
# 12   LONZA  2021-10-13                  Scientist Formulation Development
# 13   LONZA  2021-10-13        Director Commercial Development (Mammalian)
# 14   LONZA  2021-10-13  Technical Proposals Manager, Drug Product Serv...
# 15   LONZA  2021-10-13                       QC Planner/Scheduler (m/f/d)
# 16   LONZA  2021-10-13                Lead Scientist, Process Development
# 17   LONZA  2021-10-13         Quality Network Head Drug Product Services
# 18   LONZA  2021-10-13                          QC Lab Systems Specialist
# 19   LONZA  2021-10-13                            Technical Sales Manager
# 20   LONZA  2021-10-13   Lead Scientist, Physico-Chemical Quality Control
# 21   LONZA  2021-10-13                                Program Manager DPS
# 22   LONZA  2021-10-13  Head of Physico-Chemical Quality Control Drug ...
# 23   LONZA  2021-10-13       Senior Program Manager Drug Product Services
# 24   LONZA  2021-10-13  Senior Principal Scientist / Group Head Bioana...
# 25   LONZA  2021-10-13                        Capital Projects Specialist
# 26   LONZA  2021-10-13                               Integration Engineer
# 27   LONZA  2021-10-13                              Integration Architect
# 28   LONZA  2021-10-13  Associate Director, Digital Portfolio Testing ...
# 29   LONZA  2021-10-13  Principal Scientist / Group Lead Formulation D...
# 30   LONZA  2021-10-13         Digital HR Reporting & Insights Specialist
# 31   LONZA  2021-10-13                           Digital HR Security Lead
# 32   LONZA  2021-10-13        Sales & Operations – CoE Specialist (m/f/d)
# 33   LONZA  2021-10-13                IT Strategy Development & Team Lead
# 34   LONZA  2021-10-13  •\tInternal Auditor/ Audit Manager (with finan...
# 35   LONZA  2021-10-13                      Strategic Growth Project Lead
# 36   LONZA  2021-10-13              Strategic Growth Project Lead (f/m/d)
# 37   LONZA  2021-10-13                       Scientist Forensic Chemistry
# 38   LONZA  2021-10-13              Transport Excellence Director (m/f/w)
# 39   LONZA  2021-10-13                           Business Analyst Digital
# 40   LONZA  2021-10-13          Intern – Global Warehouse Strategy (100%)
# 41   LONZA  2021-10-13              Global Head of Finance Commercial CHI
# 42   LONZA  2021-10-13  Principal / Associate Principal Scientist - An...
# 43   LONZA  2021-10-13           Demand Planning – CoE Specialist (m/f/d)
# 44   LONZA  2021-10-13                           Trade Compliance Manager
# 45   LONZA  2021-10-13                 Regional Employer Brand Lead, EMEA
# 46   LONZA  2021-10-13            Head Supply Chain Drug Product Services
#
#                                    Location                              Links
# 0   Head Supply Chain Drug Product Services   https://www.lonza.com/jobs/R3784
# 1   Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R26093
# 2   Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R36672
# 3   Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R38061
# 4   Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R26740
# 5   Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R37116
# 6   Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R36666
# 7   Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R34759
# 8   Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R38059
# 9   Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R26202
# 10  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R37629
# 11  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R38010
# 12  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R38190
# 13  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R32511
# 14  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R36047
# 15  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R35779
# 16  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R37572
# 17  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R35051
# 18  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R38217
# 19  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R33662
# 20  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R38151
# 21  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R34828
# 22  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R37020
# 23  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R38602
# 24  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R37062
# 25  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R36230
# 26  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R30258
# 27  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R30257
# 28  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R24283
# 29  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R37633
# 30  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R37914
# 31  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R38808
# 32  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R34541
# 33  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R34735
# 34  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R34176
# 35  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R37089
# 36  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R38647
# 37  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R37169
# 38  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R38306
# 39  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R36196
# 40  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R37775
# 41  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R38764
# 42  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R26700
# 43  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R34542
# 44  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R37103
# 45  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R36569
# 46  Head Supply Chain Drug Product Services  https://www.lonza.com/jobs/R38621

# %%
# CREANDO DIRECTORIO CON FECHA DE EJECUCION
# RUTA -> C:\Users\lecun\Dropbox\Mi PC (LAPTOP-URCP74CR)\Desktop\Job_Bot_CH\job_bot_ch\Victor Lecuna\Pruebas_Job_Bot_CH,

date_dir = str(datetime.date.today())

if os.path.isdir('C:/Users/lecun/Dropbox/Mi PC (LAPTOP-URCP74CR)/Desktop/Job_Bot_CH/job_bot_ch/Victor Lecuna/Pruebas_Job_Bot_CH/' + date_dir):
    print('La carpeta existe.')
    
else:
     
    directorio = 'C:/Users/lecun/Dropbox/Mi PC (LAPTOP-URCP74CR)/Desktop/Job_Bot_CH/job_bot_ch/Victor Lecuna/Pruebas_Job_Bot_CH/' + date_dir
    
    try:
        os.mkdir(directorio)
        
    except OSError:
        print("La creación del directorio %s falló" % directorio
        
      else:
              print("Se ha creado el directorio: %s" % directorio)
# Out:
#   File "C:\Users\lecun\AppData\Local\Temp/ipykernel_31588/3710577941.py", line 19
#     else:
#     ^
# SyntaxError: invalid syntax
